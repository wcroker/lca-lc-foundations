# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital. Any future human settlement would be governed by international agreements rather than a single capital city. If you’re thinking of fiction, you might see names like “Lunapolis” or “Moon City,” but those aren’t real.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 655, 'prompt_tokens': 13, 'total_tokens': 668, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Ctkhv7T4rVr0CftBzyKacPVEGOiV3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8177-01ef-7f50-9b9e-b5df660fae08-0', usage_metadata={'input_tokens': 13, 'output_tokens': 655, 'total_tokens': 668, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or permanent population, so it has no capital. Any future human settlement would be governed by international agreements rather than a single capital city. If you’re thinking of fiction, you might see names like “Lunapolis” or “Moon City,” but those aren’t real.

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-Ctkhv7T4rVr0CftBzyKacPVEGOiV3',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 655,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 576,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 668}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country or government, so it has no capital or cities. If you’re thinking of fiction, some works name a fictional capital (e.g., Lunapolis), but that’s not real.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-5")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# The Moon doesn't have a capital because it's not a country or inhabited territory with a government. It's Earth's natural satellite - a celestial body with no permanent population or political structure.
#
# If you're interested in lunar geography, notable locations include the Sea of Tranquility (where Apollo 11 landed) or the lunar south pole (a target for future missions). But none of these would be considered a "capital" in any meaningful sense.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# That's a fun question that plays on our understanding of what a capital city is!
#
# Technically, the Moon doesn't have a capital city because it's not a country or a populated place in the way Earth is. There are no governments, no permanent settlements, and therefore no need for a capital.
#
# However, if we were to imagine a "capital" based on significance or a central point of human activity, there are a few contenders in a hypothetical future:
#
# *   **The Apollo Landing Sites:** Specifically, **Tranquility Base** (where Apollo 11 landed and Neil Armstrong first walked on the Moon) would be a strong contender due to its historical importance.
# *   **Future Lunar Bases:** If humanity establishes permanent bases, the **command center or administrative hub of the largest or first established base** would likely become its de facto capital.
#
# But for now, the answer is **the Moon has no capital.**

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-5")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='bda60423-3ed5-4dd4-8ff6-39c4b42e14ac'),
#               AIMessage(content='There isn’t one. The Moon isn’t a country and has no government, so it has no capital.\n\nIf humans someday establish a lunar settlement, they’d decide on an administrative hub or capital themselves. In fiction and worldbuilding you might see names like Lunapolis, Selene City, or Luna City, but these are imaginative rather than real. If you’re thinking about a realistic scenario, I can help sketch governance ideas for a future lunar colony.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 868, 'prompt_tokens': 13, 'total_tokens': 881, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtksuxPEmzQLO9mlyPF1eRnrv2Am5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b8181-62d5-79f0-b8c9-75df70444032-0', usage_metadata={'input_tokens': 13, 'output_tokens': 868, 'total_tokens': 881, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital.
#
# If humans someday establish a lunar settlement, they’d decide on an administrative hub or capital themselves. In fiction and worldbuilding you might see names like Lunapolis, Selene City, or Luna City, but these are imaginative rather than real. If you’re thinking about a realistic scenario, I can help sketch governance ideas for a future lunar colony.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='bedb2913-072b-46fd-b708-f21d91737288'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='c19abb70-ced8-4377-ad5e-122e40d4ff69'),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='92a39612-8d48-4b59-bf53-ed6f11b14f1d'),
#               AIMessage(content='Nice idea! Here’s a richer, fictional portrait of Luna City—the capital of the Moon. It’s a setting you can drop into sci‑fi stories, games, or world-building.\n\nQuick concept\n- Luna City is a federated capital built into a sunlit lunar plain (near a Mare region, with some districts near a crater rim for scenic views). It combines high-density domed neighborhoods, research corridors, and a vibrant civic center. Housing, governance, science, and culture all sit under a shared shield and life-support system that protects residents from radiation and micrometeorite dust.\n\nHistory and purpose\n- Founded in the late 21st century as the first multi‑national lunar capital, Luna City grew from a cluster of research stations into a full civic hub.\n- It serves as the administrative heart of the Moon’s lunar federation, hosting government chambers, interplanetary databases, and the Lunar University.\n- Early decades focused on life-support reliability, radiation shielding, and closed-loop ecosystems. Later, the city expanded with farms, workshops, and cultural districts to attract residents beyond scientists.\n\nGovernment and society\n- Political structure: a Lunar Federation with a Council of District Representatives, a Prime Administrator, and a Lunar Court. Decisions emphasize resource sharing, environmental stewardship, and transparent governance.\n- Districts have a degree of autonomy, with a central budget geared toward science funding, public health, and education.\n- Citizens come from many Earth nationalities and have civic duties, education requirements, and representation in the Council.\n- Public life emphasizes community gardens, public forums, and open data portals for transparency.\n\nEconomy and industry\n- Core industries: research and development, life-support tech, in-situ resource utilization (water ice, minerals), and manufacturing inside pressure domes.\n- Energy is primarily solar, via large exterior arrays and shadow-mining mirrors. Some districts use compact nuclear batteries for high-demand periods.\n- Secondary sectors include lunar tourism (glassed skylines, tours of crater rims), biosciences in microgravity, and artisanal crafts unique to lunar life.\n- Trade happens with Earth and orbital platforms, including exchange of water ice, gases, and advanced materials.\n\nCity design, districts, and daily life\n- Central core: a cylinder of interconnected domes housing government buildings, a large plaza, and the Moon University’s main campus. The core is the civic heart and a social hub.\n- Residential belts: stacked, modular domes with adaptable interior layouts. Most units have gravity adjusted by rotor and treadmill zones, with common gardens in every neighborhood.\n- Research and industry corridors: cleanrooms, test farms, and weather-controlled laboratories connected by airless transit tubes and maglev walkways.\n- Subsurface farms: pressurized farms beneath the surface help stabilize food supply and regulate temperature.\n- Transport: a network of surface maglev shuttles, surface-to-subsurface elevators, and airlock corridors to move between levels. Personal mobility favors compact, low-drag rovers and electric hop-boards for short hops.\n- Life and culture: residents follow a rhythm shaped by a long lunar day (about 29.5 Earth days) but the city uses artificial daylight for perception, scheduling work in 24-hour blocks when needed. Education emphasizes STEM, lunar history, and planet-friendly ethics. Public spaces host art in illuminated domes, zero‑gravity performances, and seasonal festivals tied to Earth’s calendar.\n\nLandmarks, institutions, and culture\n- The Solaris Ring: a solar-energy bastion around the city, with viewing decks and public education centers about energy harvesting.\n- Central Dome: the administrative hub and the main public square, where citizens gather for announcements, debates, and festivals.\n- Moon University: a graduate-and-applied-resear ...

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is not a real place today, but a rich, plausible concept you can use for fiction, worldbuilding, games, or a campaign setting. Here’s a detailed, self-contained profile you can pull from or adapt.
#
# What Luna City is
# - A capital city built on the Moon, conceived as the political, economic, and cultural heart of Lunar civilization.
# - Located at or near a lunar polar region (often imagined near Shackleton Crater’s rim or a similar water-ice deposit) to leverage sunlight for power and access to frozen volatiles for life support and fuel.
# - A hub for governance, industry, science, and diplomacy among lunar settlements and Earth nations or corporations with lunar interests.
#
# Government and politics
# - Government shape: A representative lunar government with a Prime Administrator or President, a Lunar Council, and specialized ministries (Finance, Resources, Science & Exploration, Security & Space Traffic, Culture & Education).
# - Legal framework: A Lunar Charter and a set of planetary/space laws, balancing autonomous lunar governance with Earth-based treaties. Rights and responsibilities emphasize life support stewardship, resource sharing, and transparent governance.
# - Power centers: The City Core (administrative and diplomatic heart), the Port District (freight and transport), and the Dome Ring (residential, cultural life, education).
# - Current leadership (example): A Prime Administrator who coordinates Earth-Lunar relations, a Lunar Council representing district constituencies, and a Chief of Security overseeing inter-city safety and space traffic.
#
# Urban layout and districts
# - The Core: Tall glass-and-regolith towers, government ministries, courts, archives, and the mayoral residence. A symbol of stability and order.
# - The Dome Ring: A belt of interconnected inflatable or rigid-habitat domes housing most residents, clinics, schools, and cultural venues. Built to shield residents while maximizing daylight and views.
# - The Greenbelt: Large closed-loop greenhouses and farms producing food, oxygen, and pharmaceutical crops; research labs mixed with public gardens.
# - The Port District: Vehicle hubs, airlocks, maintenance yards, and the main spaceport for vessels docking from Earth or other lunar sites.
# - The Edge Districts: Industrial zones with manufacturing, 3D printing facilities, regolith-processing plants, and energy storage; nearby, vacuum corridors and radiation shields double as transit routes.
# - The Cultural Quarter: Museums, theaters, music venues, libraries, and universities. Public art integrates with solar sculptures and architectural forms in lunar regolith.
#
# Climate, environment, and living conditions
# - Environment: The Moon’s no-atmosphere, extreme surface conditions, and 1.62 m/s^2 gravity. Luna City exists inside a shielded habitat mesh—think multiple layers of radiation shielding, airlocks, and controlled internal climate.
# - Habitats: A mix of pressure domes, pressurized modules, and underground or partially underground living spaces to minimize radiation exposure and micrometeoroid risk.
# - Day-night cycle: About 14 Earth days of sunlight and 14 days of darkness. Power is primarily solar, with advanced battery storage and nuclear or fusion backups for long eclipse periods.
# - Water and life support: Recovered water from cometary/ice sources, recycled air and water loops, hydroponic gardens, and bioreactors producing food and oxygen.
#
# Technology and infrastructure
# - Energy: Solar arrays, with fusion or advanced fission backups; energy management coordinated across districts.
# - Transportation:
#   - Local: Rosters of electric lunar rovers, maglev shuttles inside the Dome Ring, and short-range transit via vacuum tubes or low-gravity trams.
#   - Interplanetary: Orbit-to-ground shuttles, hydrogen/oxygen depots, and a spaceport capable of handling freight freighters and passenger ships.
#   - Special infrastructure: A network of airlocks, emergency corridors, and radiation shelters integrated into the urban fabric.
# - Industry: Regolith processing (for construction materials and shielding), 3D-printed components, life-support systems production, and biotech labs growing food in closed loops.
# - Housing and architecture: A mix of modular units and regolith-encased buildings; aesthetic features blend white/gray regolith tones with glassy panels, solar accents, and sculpted lunar art.
#
# Economy and resources
# - Main resources: Water ice (for life support and fuel), regolith-derived materials (for construction and manufacturing), and advanced manufacturing capabilities (3D printing, bioprocessing, and optics).
# - Economy drivers:
#   - Public sector: Governance, education, research, and public services.
#   - Private sector: Lunar mining contractors, habitat manufacturers, biotech firms, spaceport services, and tourism.
#   - Trade: Export of water-derived products, rare lunar materials, and high-tech components to Earth or other settlements.
# - Currency and finance: A Lunar Credit or similar currency backed by a mix of Earth support, lunar assets, and service-based revenue.
#
# Society and culture
# - Population: A diverse mix of scientists, engineers, civil servants, artists, educators, and settlers. Families live in multi-generational housing clusters with strong community support networks.
# - Language and education: A blend of Earth languages with a common lunar lexicon; strong emphasis on STEM, space history, and planetary ethics. Universities offer programs in astrosociology, geology, life support engineering, and lunar architecture.
# - Culture and daily life: The culture emphasizes resilience, curiosity, and cooperation. Public art and music celebrate the Moon’s beauty and challenges. Cuisine leans on hydroponic greens, algae-based proteins, and Earth-imported staples augmented by lunar-grown crops.
# - Holidays and rituals: Commemorations of successful landing anniversaries, water-ice discovery milestones, and inter-world peace celebrations. Periodic “sunrise festivals” timed with solar array maintenance to honor energy resilience.
#
# Notable landmarks and features
# - Helios Tower: A solar-powered observatory and communications hub with panoramic lunar views.
# - The Beacon of Tranquility: A monument and civic space dedicated to lunar peace and scientific progress.
# - The Archive Dome: A vast library and museum preserving lunar heritage, settlers’ records, and sample regolith cores.
# - The Greenhouse Crescent: A long, garden-like crescent feeding the city and serving as a public park and research site.
# - The Gate of Doors: A dramatic entry plaza with multiple airlocks, symbolizing openness to Earth and other lunar settlements.
#
# History and lore (a plausible backstory)
# - Founding era: Early 22nd century, after international partnerships established free-trade, research, and settlement zones on the Moon.
# - Growth: Luna City grew from a government outpost to a full-fledged capital as ice deposits and in-situ resource utilization reduced dependence on Earth for life support.
# - Conflicts and diplomacy: Tensions over resource distribution and governance rights give way to a shared lunar identity and interstellar diplomacy initiatives. Cultural institutions celebrate resilience and scientific achievement.
# - Current arc: Luna City strives for sustainable autonomy while maintaining constructive relations with Earth, other colonies, and commercial space operators.
#
# Characters and factions (for storytelling or games)
# - The Prime Administrator: A skilled diplomat and technocrat balancing Earth relations with lunar independence.
# - Lunar Council Members: Representatives from districts (Core, Greenbelt, Port District, Edge District) with competing priorities.
# - Chief of Security: Oversees civil order, space traffic, and disaster response; works with planetary defense teams.
# - Chief Scientist: Heads the interdisciplinary lab complex, pushing research in life support, resource utilization, and habitat design.
# - Cultural Commissioner: Promotes arts, public education, and cross-district collaborations.
#
# Story prompts and game hooks
# - A water-ice crisis exposes a buried political conspiracy about who controls the ice and how it’s allocated.
# - A solar flare knocks out a portion of Luna City’s power grid; citizens rally around a volunteer emergency corps.
# - A diplomatic summit with Earth nations uncovers a disagreement over resource sharing, forcing the city to navigate a tense standoff without escalating to conflict.
# - A cultural festival reveals a long-lost lunar artifact that hints at an earlier, unknown phase of lunar civilization.
#
# If you’re writing or designing a game, I can tailor Luna City to a specific tone (hard sci-fi, hopeful utopia, cyberpunk, gritty survival, etc.), adjust for scale (smaller settlement vs. sprawling metropolis), or develop a ready-to-use lore bible (timeline, faction sheets, map descriptions, key NPCs). Let me know your preferred vibe, medium, and any constraints (realism level, audience, or era), and I’ll customize it.
