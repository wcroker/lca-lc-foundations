# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## No memory

# %%
from langchain.agents import create_agent


agent = create_agent(
    "gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")

response = agent.invoke(
    {"messages": [question]} 
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='496cb540-042c-4959-b974-ef7e23040a14'),
#               AIMessage(content='Hi Seán! Nice to meet you. Green is a great colour—calming and vibrant. How can I help you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 484, 'prompt_tokens': 18, 'total_tokens': 502, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtmgMEYQaFrIcJSWaUdZ2GLrIbQ6Z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81ea-d477-7e21-b457-f8613fa99471-0', usage_metadata={'input_tokens': 18, 'output_tokens': 484, 'total_tokens': 502, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
question = HumanMessage(content="What's my favourite colour? What's my name?")

response = agent.invoke(
    {"messages": [question]} 
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's my favourite colour? What's my name?", additional_kwargs={}, response_metadata={}, id='381ddc60-78f1-49b5-aefb-d00291eda024'),
#               AIMessage(content='I don’t know your name or your favourite colour yet. If you tell me what you’d like me to call you and what your favourite colour is, I’ll use them in this chat (for this conversation). Want to share those? Or should I try to guess?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1153, 'prompt_tokens': 15, 'total_tokens': 1168, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1088, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtmhJOySZXrL5U5Bv2VxYY3TFUguw', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81eb-bb8f-7683-9142-20ecc6eda57f-0', usage_metadata={'input_tokens': 15, 'output_tokens': 1153, 'total_tokens': 1168, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1088}})]}

# %% [markdown]
# ## Memory

# %%
from langgraph.checkpoint.memory import InMemorySaver  


agent = create_agent(
    "gpt-5-nano",
    checkpointer=InMemorySaver(),  
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Hello my name is Seán and my favourite colour is green")
config = {"configurable": {"thread_id": "1"}}

response = agent.invoke(
    {"messages": [question]},
    config,  
)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='39b32ed3-2d79-4b73-9a6d-86c449221148'),
#               AIMessage(content='Nice to meet you, Seán! Green is a wonderful color—calming and lively. Do you have a favorite shade of green or a green thing you especially love? If you’d like, I can help with green-themed ideas—nature, color palettes, Irish culture, or a quick green trivia quiz. What would you like to chat about today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 529, 'prompt_tokens': 18, 'total_tokens': 547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Ctmic7W7kqC7rFXJ4PVNfAE8WP6DV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81ec-f7fd-70d0-9e50-32da7934d34e-0', usage_metadata={'input_tokens': 18, 'output_tokens': 529, 'total_tokens': 547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]}

# %%
question = HumanMessage(content="What's my favourite colour?")

response = agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Hello my name is Seán and my favourite colour is green', additional_kwargs={}, response_metadata={}, id='39b32ed3-2d79-4b73-9a6d-86c449221148'),
#               AIMessage(content='Nice to meet you, Seán! Green is a wonderful color—calming and lively. Do you have a favorite shade of green or a green thing you especially love? If you’d like, I can help with green-themed ideas—nature, color palettes, Irish culture, or a quick green trivia quiz. What would you like to chat about today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 529, 'prompt_tokens': 18, 'total_tokens': 547, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Ctmic7W7kqC7rFXJ4PVNfAE8WP6DV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81ec-f7fd-70d0-9e50-32da7934d34e-0', usage_metadata={'input_tokens': 18, 'output_tokens': 529, 'total_tokens': 547, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}}),
#               HumanMessage(content="What's my favourite colour?", additional_kwargs={}, response_metadata={}, id='c2c1b64c-e5e9-4118-995e-1356ee3f732d'),
#               AIMessage(content='Your favourite colour is green. Would you like to talk about green shades or use green in a project or activity?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 288, 'prompt_tokens': 105, 'total_tokens': 393, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtmiuibMwm4XUGlqD8uOSXTdMYJAJ', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81ed-4039-7fe2-b426-3c52b9c56182-0', usage_metadata={'input_tokens': 105, 'output_tokens': 288, 'total_tokens': 393, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})]}
