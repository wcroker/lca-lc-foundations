# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def square_root_tool(x: float) -> float:
    return x ** 0.5

# %%
square_root_tool.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[square_root_tool],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# √467 ≈ 21.61018278497431
#
# Rounded:
# - to 4 decimals: 21.6102
# - to 2 decimals: 21.61
#
# (467 is not a perfect square, so the exact value is irrational.)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='c5ae5426-9961-4344-99ae-8da04349f978'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 920, 'prompt_tokens': 158, 'total_tokens': 1078, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Ctm8uOVJL8axWzI4pIrWNCqq8BOdN', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b81cb-2f01-7393-a784-6d4e17773b64-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_4t9535wzLVk9bBs1Pj7nBZnF', 'type': 'tool_call'}], usage_metadata={'input_tokens': 158, 'output_tokens': 920, 'total_tokens': 1078, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='264e3409-c51c-4515-8297-c6a4a87a05f9', tool_call_id='call_4t9535wzLVk9bBs1Pj7nBZnF'),
#  AIMessage(content='√467 ≈ 21.61018278497431\n\nRounded:\n- to 4 decimals: 21.6102\n- to 2 decimals: 21.61\n\n(467 is not a perfect square, so the exact value is irrational.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 446, 'prompt_tokens': 193, 'total_tokens': 639, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Ctm92uxj6iLWAQE77AJ8KqXzOUIOE', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81cb-4e18-7933-a0f9-ab1da5d2c54e-0', usage_metadata={'input_tokens': 193, 'output_tokens': 446, 'total_tokens': 639, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'call_4t9535wzLVk9bBs1Pj7nBZnF', 'type': 'tool_call'}]
