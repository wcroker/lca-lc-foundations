# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano"
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# I’m trained on data up to June 2024. That means I’m reliable for information, events, and standards up to that point. I don’t have real-time browsing by default, so I can’t verify or pull in new facts after that cutoff unless you enable browsing or provide sources.
#
# If you need the latest details (post-June 2024), you can:
# - Tell me what you’re looking for and I’ll help reason about it or compare it to prior knowledge.
# - Share a link or key facts from post-cutoff sources, and I can help interpret them.
# - Enable browsing (if available in your setup) to fetch current information.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': 'The current mayor is Democrat Daniel Lurie.',
#    'score': 0.9581049,
#    'raw_content': None},
#   {'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie - Wikipedia',
#    'content': 'Daniel Lawrence Lurie (born 4 February 1977) is an American politician and philanthropist who is the 46th and current mayor of San Francisco, serving since 2025',
#    'score': 0.9284155,
#    'raw_content': None},
#   {'url': 'https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0',
#    'title': "San Francisco's new mayor is starting to unite the fractured city",
#    'content': 'San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.',
#    'score': 0.8763069,
#    'raw_content': None},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor - SF.gov',
#    'content': 'Daniel Lurie is the 46th Mayor of the City and County of San Francisco.',
#    'score': 0.86052185,
#    'raw_content': None},
#   {'url': 'https://www.latimes.com/california/story/2025-04-14/the-vibe-shift-is-real-as-san-francisco-mayor-daniel-lurie-becomes-hometown-hype-man',
#    'title': "Daniel Lurie is San Francisco's nerdy new mayor — and hype man",
#    'content': "SAN FRANCISCO — When Daniel Lurie won election in November as San Francisco's new mayor, he knew there were daunting challenges ahead: the",
#    'score': 0.8098936,
#    'raw_content': None}],
#  'response_time': 0.68,
#  'request_id': '023d6b13-cb7c-4bcc-8fee-94fa3e0fb805'}

# %%
agent = create_agent(
    model="gpt-5-nano",
    tools=[web_search]
)

question = HumanMessage(content="Who is the current mayor of San Francisco?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Who is the current mayor of San Francisco?', additional_kwargs={}, response_metadata={}, id='5f896a59-04c4-4ea7-adab-0cdd87713bd5'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 347, 'prompt_tokens': 133, 'total_tokens': 480, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 320, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtmHf7uMlXjTP4lG4zNnE5tQsX6Fw', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b81d3-7979-76a3-a2fd-b619e659cee9-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'current mayor of San Francisco'}, 'id': 'call_wwqwXNO9divEM59bKJpdTMTx', 'type': 'tool_call'}], usage_metadata={'input_tokens': 133, 'output_tokens': 347, 'total_tokens': 480, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 320}}),
#  ToolMessage(content='{"query": "current mayor of San Francisco", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/Mayor_of_San_Francisco", "title": "Mayor of San Francisco", "content": "The current mayor is Democrat Daniel Lurie.", "score": 0.9990746, "raw_content": null}, {"url": "https://apnews.com/article/san-francisco-new-mayor-liberal-city-81ea0a7b37af6cbb68aea7ef5cc6a4f0", "title": "San Francisco\'s new mayor is starting to unite the fractured ...", "content": "San Francisco Mayor Daniel Lurie, a political newcomer and Levi Strauss heir, has marked his first 100 days with a hands-on, business-friendly approach.", "score": 0.9978002, "raw_content": null}, {"url": "https://www.youtube.com/watch?v=Qvl6AMoZCoI", "title": "San Francisco Mayor-elect Daniel Lurie on transforming the city", "content": "In a CNBC exclusive, San Francisco\'s new Mayor-elect Daniel Lurie sits down with Kate Rogers to talk about bringing remote workers back,", "score": 0.9883128, "raw_content": null}, {"url": "https://en.wikipedia.org/wiki/Daniel_Lurie", "title": "Daniel Lurie", "content": "Daniel Lawrence Lurie (born 4 February 1977) is an American politician and philanthropist who is the 46th and current mayor of San Francisco, serving since 2025", "score": 0.9863631, "raw_content": null}, {"url": "https://www.politico.com/news/magazine/2025/02/23/daniel-lurie-san-francisco-mayor-00205527", "title": "Mayor Lurie Tries to Bloomberg-ize San Francisco", "content": "SAN FRANCISCO — Daniel Lurie began the morning of his inauguration as this city\'s new mayor last month at a soup kitchen before walking with", "score": 0.9850429, "raw_content": null}], "response_time": 0.64, "request_id": "2af07216-e240-4dd6-a812-2884f978bfc9"}', name='web_search', id='29b6a824-c747-4c32-a134-adb16487fb93', tool_call_id='call_wwqwXNO9divEM59bKJpdTMTx'),
#  AIMessage(content='Daniel Lurie is the current mayor of San Francisco. He took office in 2025 and serves as the city’s 46th mayor. If you’d like, I can pull an official confirmation from the city’s website.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 760, 'prompt_tokens': 670, 'total_tokens': 1430, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-CtmHlk3KmQ88VbSmuEdSUDF2aaXay', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b81d3-8ee0-73b3-85af-ca989a7d081d-0', usage_metadata={'input_tokens': 670, 'output_tokens': 760, 'total_tokens': 1430, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})]

# %%
print(response['messages'][-1].content)
# Out:
# Daniel Lurie is the current mayor of San Francisco. He took office in 2025 and serves as the city’s 46th mayor. If you’d like, I can pull an official confirmation from the city’s website.

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r
