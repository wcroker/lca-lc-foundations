# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of Italy?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# Rome is the capital of Italy.
#
# If you’d like a science-fiction twist, I can design a futuristic capital for Italy—tell me the vibe (orbital megacity, subterranean hive beneath the ancient ruins, floating platforms, etc.) and I’ll create it.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'cityscape-rome-ancient-centre-italy.png', 'type': 'image/png', 'size': 985457, 'content': <memory at 0x0000027B7F1A3C40>, 'last_modified': datetime.datetime(2026, 1, 4, 1, 46, 48, 780000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# From the image you shared, the capital is Roma Prime—a city that wears its ancient stones like a living memory, while its glass and alloy towers push the sky a little higher each year.
#
# What Roma Prime is like
# - Name and role: Roma Prime is the political heart of the realm, the seat of the Republic of Aeterna. It blends imperial ceremony with planetary-scale governance, where centuries-old rituals accompany real-time AI councils. The city keeps its oldest ruins as civic monuments, not museum pieces.
# - Geography and layout: The core sits on a tidal river delta, ringed by olive-green hills and terraces. The ancient forum sits at the center, surrounded by a grid of elevated avenues and sun-lit piazzas. Over time, new districts have grown outward: the Senate Dome, the Market of Echoes, the Docks of Lumen, and the upward-shooting Arcologies that crown the hills.
# - Architecture and atmosphere: You can feel the past in every stone—the stones themselves seem to remember footsteps from a long-vanished era. Yet the material is modern: programmable concrete, adaptive glass, and living moss terraces that regulate climate and air quality. The Colosseum Magnus dominates the western edge of the core, a multi-use amphitheater that hosts public debates, holo-spectacles, and gravitational experiments.
# - Governance and society: The city is ruled by a hybrid system—an elected Senate that consults with an AI oracle network, and a Praetorian Guard made of veterans and autonomous guardians. Civic life is highly participatory: citizens vote on major issues in open-air assemblies that occur beneath the arches of the ancient forum, and every public data feed is visible to anyone with a portable viewer.
# - Culture and daily life: Festivals fuse antiquity with futurism. Lantern Night lights up the river with bioluminescent barges; Saturnalia Reboot reimagines old rites as augmented-reality performances. The spoken language is a revived Latin accent with local slang and digital shorthand; music blends ancient choral traditions with synth and drone bases. People commute along viae-lanes—self-driving carriages and magnetic-lev platforms—while small artisans work at the borders where old stone meets new metal.
# - Technology and economy: Roma Prime is powered by a network of solar domes and tidal turbines that sit beneath public plazas, harvesting energy with minimal disruption to the historic fabric. 3D-printed architecture and modular monuments let the city repair and repurpose itself after every festival, while a swarm of drones handles maintenance, archaeology, and rescue operations. The Market of Echoes trades not just goods but data: encrypted digital relics from space habitats, micro-factories that print tools on demand, and archival chips that store memories for future generations.
# - Landmarks you’d recognize in the image’s spirit:
#   - Colosseum Magnus: a circular integument of stone and living bio-mesh that hosts civic games, ceremonial matches, and scientific demonstrations.
#   - Arch of Lectern: a slender, gravity-cancelled archway that serves as an entrance to the administrative heart, projecting holographic proclamations on demand.
#   - Temple of the Sun (observatory): a glass-domed temple atop a hill that maps solar activity and guides the city’s energy flow.
#   - Forum of Echoes: an open agora where debates, markets, and broadcasts echo through time as AR histories replay for new citizens.
#   - The Docks of Lumen: a waterfront zone where orbital freight arrives, processed by AI stevedores and redistributed to districts via elevated tramways.
#
# Life and challenges
# - The city is proud and resilient, but not utopian. It wrestles with preserving heritage while embracing automation, balancing public access with security, and keeping old neighborhoods livable as new districts rise.
# - Tensions often surface between the “Guardians of the Past” who want strict preservation and the “Civic Innovators” who push for more integrated technology. Both sides share a common love for Roma Prime’s soul—the sense that the past and the future are not enemies but partners.
#
# A quick scene
# During the Lantern Night festival, the Colosseum Magnus glows with bioluminescent veins that pulse in time with a live choir and a drone orchestra. An open-air forum is projected onto the ancient stones, showing real-time citizen proposals. A student from the Docks of Lumen steps forward with a plan to reroute energy from the night markets to preserve a section of the old aqueduct. The AI oracle offers a holographic demo, the crowd cheers, and the city shifts its energy grid with a polite hum, proof that Roma Prime can honor its roots while stepping boldly into the future.
#
# Would you like me to tailor Roma Prime to a particular setting—different planet, era, or political system? If you tell me the tone (grand epic, noir future, utopian hub, etc.), I can adapt landmarks, customs, and conflicts to fit.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.82it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-4o-audio-preview',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# It sounds like you’ve described an MP3 file using Base64 encoding. Unfortunately, I cannot directly determine the contents or details from just that description.
#
# However, if you provide the actual Base64 data or upload the audio file, I can listen to the content of the audio and give you some information about what’s in it, such as whether it is music, speech, or something else, as well as general observations regarding the content. Please go ahead and provide the file or data, and I’ll do my best to assist!
